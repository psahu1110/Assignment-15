# %%
import requests 
from bs4 import BeautifulSoup as bs
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
iphone_reviews = []

# %%
for i in range (1,21):
    ip=[]
    url ="https://www.amazon.in/product-reviews/B08L5T44CQ/ref=acr_dp_hist_5?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews#reviews-filter-bar="+str(i)
    response = requests.get(url)
    soup = bs(response.content,"html.parser")
    reviews = soup.findAll("span",attrs = {"class","a-size-base review-text review-text-content"})
    for i in range(len(reviews)):
        ip.append(reviews[i].text)
    iphone_reviews = iphone_reviews+ip

# %%
with open("iphone.txt","w",encoding = 'utf-8') as output:
    output.write(str(iphone_reviews))

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
red_rev_string = " ".join(iphone_reviews)

# %%
red_rev_string = re.sub("[^A-Za-z" "]+"," ",red_rev_string).lower()
red_rev_string =re.sub("[0-9" "]+"," ",red_rev_string)

# %%
red_rev_string
# Out:
# ' as usual great premium phone of prosthis time the apple iphone uses the right angled bezel of the iphone s which looks square and it feels good in the hand it feels better than the sleek bezel of the iphone x especially the mm thickness with right angles the border is particularly stylish the camera is awesome the night view mode turns on automatically and the imaging effect is really good video stabilization is also good the filter mode is quite good many android phones are still many miles away from these tones even though there are good imitations apple was able to improve its tones image quality is perfect and there is little or no noise even in a low light environment signal nothing to say it is much better in iphone pro wifi also consthere is a problem with the hand handling of this phone oh yes the iphone is light to handle however it is not easy to handle the iphone comes with metal edges and there have been multiple complaints with respect to these edges if you handle this phone for a long time as your hand becomes a bit moist the metal becomes slippery to prevent your phone from falling to the ground you will sub consciously tighten your grip on the phone several reports have shown that tightening your grip on the iphone leaves you with a scar on your palm this means that the iphone edges are perhaps too sharp this is a major flaw in the design of this phone that will force users to stick with a phone case please note that users with thick skin like mine do not experience this problem the iphone battery capacity and performance are lower than the previous generation final verdictoverall i think apple fanboys will be very comfortable with this device there is a very serious flaw with the design though apple may need to make those edges smoother in subsequent remakes for now stick with your phone case to avoid injuries if your skin is pretty thick like mine then you do not have a problem we can safely say that the network and camera of the iphone are great however the battery battery battery there is nothing positive about the iphone battery it is smaller than its predecessor in all ramifications the charging capacity is also slow i give this smartphone a pass mark in every other aspect save the battery that is a huge minus from an android fanboy point of view the iphone battery is at best laughable been using iphone pro since january i love it many used to tell me that buying pros online isn t safe but it s working well so far i love it hello all first of all i would like to thank the seller for sending me a genuine product if you are trying to spend a good amount of money on buying this product and you see the first review on this page is really bad you become skeptical and think not twice but more than that to buy it from this seller but i received a genuine product regarding the phone i think i need not explain much here since there is enough youtube videos on detailed review but overall its good phone and worth the price only cons that i could see after using it for a weeks is that the batter will only last for a day with good screen time like watching videos and spending good time in social media but this is more than enough for average users since i was moving from android i had some issue in data chat sync but you can go through youtube for getting all workaround for your issues i feel proud to be an iphone user for past years moving from i to i pro was a big jump and apple has proved again with its high performance chip and pro cams instead of buy cheap android phones every or years i feel it s better to invest on iphones in my experience with iphones now pro maintenance on phone is very important make sure you handle the phone with care and do not drop it often minimum years one iphone will last with out any issues i was a great fan of symbian os in my s i would say ios the best compared to android just go for it recently shifted from an iphone s gb after years to an iphone pro gb the phone is very good eve ...

# %%
red_rev_words = red_rev_string.split(" ")

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
red_rev_words = [w for w in red_rev_words if not w in stop_words]

# %%
red_rev_string =" ".join(red_rev_words)

# %%
wordcloud_ip = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(red_rev_string)

# %%
plt.imshow(wordcloud_ip)

# %%
with open("negative-words.txt","r",encoding="ISO-8859-1") as neg:
  negwords = neg.read().split("\n")

# %%
negwords =negwords[37:]

# %%
red_pos = " ".join([w for w in red_rev_words if w in negwords])

# %%
wordcloud_pos = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(red_pos)

plt.imshow(wordcloud_pos)

# %%
red_unique = list(set(" ".join(iphone_reviews).split(" ")))

# %%
red_unique
# Out:
# ['low-light',
#  'really',
#  'time,',
#  '',
#  'price',
#  'Night',
#  'lag',
#  ',',
#  'usual',
#  'Minimum',
#  '4S,',
#  'Phone',
#  'Camera',
#  'too',
#  'cameras',
#  'One',
#  'perfect',
#  'first',
#  'online',
#  'great',
#  'better',
#  'June',
#  'video',
#  '20th',
#  'think',
#  'latest',
#  'makes',
#  'masks',
#  'width',
#  'time.So',
#  'comes',
#  'turns',
#  'i',
#  'years.',
#  'sharp.',
#  'stays',
#  'super',
#  'measure',
#  'save',
#  'your',
#  'higher',
#  'r',
#  'our',
#  'If',
#  'able',
#  'experience',
#  'phone',
#  'effect',
#  'however,',
#  '\nVery',
#  'aspects.It',
#  'metal',
#  'respect',
#  '3',
#  'In',
#  'time',
#  'will',
#  'there',
#  'perfect.The',
#  'of',
#  'Face',
#  'now,',
#  'particularly',
#  'slippery.',
#  'serious',
#  'Moving',
#  'health.\n',
#  'Several',
#  'important.',
#  '20’s',
#  'Pro',
#  'give',
#  'tasks',
#  'seamless.',
#  '...',
#  'right',
#  'device.',
#  'looks',
#  '&',
#  'works',
#  'Apple',
#  'away',
#  '.ConsThere',
#  'overall',
#  'here',
#  'issue',
#  'these',
#  'case',
#  'usage',
#  'games',
#  'iPhone12',
#  'stabilization',
#  'angles.',
#  'more',
#  'mode',
#  '6',
#  '2020',
#  'bezel',
#  'edges.',
#  '4K',
#  'especially',
#  'good\n',
#  'Graphite',
#  'mask',
#  'though.',
#  'gen',
#  'pros',
#  'times.',
#  'phones',
#  'looking',
#  'some',
#  'fan',
#  'problem',
#  '(Edit:',
#  'brilliant',
#  'weeks',
#  '(512GB).',
#  'DSLR',
#  'again',
#  'am',
#  'good!!!!!!!!The',
#  'best,',
#  'videos.',
#  'feel',
#  'IOS',
#  'easy',
#  'This',
#  'edges',
#  'those',
#  'day',
#  'subsequent',
#  'reports',
#  'VerdictOverall,',
#  'But',
#  'an',
#  'from',
#  'ok',
#  'scar',
#  'appliances,',
#  'excepted.Face',
#  'writing',
#  'generation.Final',
#  'youtube',
#  'now',
#  'much',
#  'against',
#  'chip',
#  'a',
#  'using',
#  'improve',
#  'media',
#  '6s',
#  'Prebooked',
#  'long',
#  'pretty',
#  'two',
#  'life.',
#  'on',
#  '\nexcellent',
#  'not',
#  'seller',
#  'outside',
#  'uses',
#  'extra',
#  'been',
#  '12MP',
#  'also',
#  'leaves',
#  'flaw',
#  'injuries.',
#  'perhaps',
#  'average',
#  'So',
#  'becomes',
#  'force',
#  '(',
#  '(9:25)',
#  'any',
#  'although',
#  'maximum',
#  'Please',
#  'ordered',
#  'money',
#  'colour',
#  "won't",
#  '12Pro',
#  'genuine',
#  '12.',
#  'taking',
#  '.**',
#  'say!',
#  'mine',
#  '.Regarding',
#  '60fps',
#  '.\n',
#  'Signal,',
#  'tightening',
#  'it',
#  'Only',
#  'border',
#  'takes',
#  'right-angled',
#  '-',
#  'Wifi',
#  'predecessor',
#  'say',
#  'storage',
#  'make',
#  'stick',
#  'There',
#  'minus.',
#  'lower',
#  'compared',
#  '\nThe',
#  'do',
#  'is',
#  'or',
#  'smoother',
#  'charging',
#  'tiny',
#  'have',
#  'sending',
#  'iPhone',
#  'spend',
#  'like',
#  'Stunning',
#  '\nI',
#  'miles',
#  'item',
#  'yes,',
#  'since',
#  ')',
#  'quality',
#  'automatically,',
#  'ever.',
#  'battery',
#  'consume',
#  'than',
#  'phone.',
#  'To',
#  'years',
#  '(32GB)',
#  'huge',
#  'that',
#  'I',
#  'mark',
#  'nothing',
#  'shots.',
#  'premium',
#  'buy',
#  'handle',
#  'noise',
#  'thickness',
#  'audio.When',
#  'proved',
#  'giving',
#  '7',
#  'month',
#  'positive',
#  'does',
#  'used',
#  'up',
#  'with',
#  'moving',
#  'passcode',
#  'it.',
#  'previous',
#  'Interestingly,',
#  'service',
#  'best',
#  'morning',
#  'RAW',
#  'last',
#  'Quality',
#  'iPhone12pro',
#  'thank',
#  'seen',
#  'avoid',
#  'software',
#  'need',
#  'it’s',
#  'Review',
#  'only',
#  'gripping',
#  'Everything',
#  'whole',
#  'iPhone.',
#  'bit',
#  ',First',
#  'be',
#  'iPhones.In',
#  'photos',
#  'ur',
#  'remakes.',
#  'Is',
#  'man,electronic',
#  'even',
#  'Go',
#  'responsive',
#  '\nHello',
#  'All',
#  'cheap',
#  'January',
#  'view',
#  'videos',
#  'all',
#  'getting',
#  'for',
#  'capacity',
#  'prevent',
#  'one',
#  'twice',
#  'moist,',
#  'The',
#  '\nRecently',
#  'display',
#  'move',
#  'superb',
#  'care',
#  'Portrait',
#  'changed',
#  'social',
#  'i12Pro',
#  'it!\n',
#  'fanboys',
#  'watching',
#  'Also',
#  'batter',
#  'heavy',
#  'aspect',
#  'skeptical',
#  'night',
#  'it!!!\n',
#  'enter',
#  'ultra',
#  'problem.***',
#  'iPhones',
#  'each',
#  "you'll",
#  "it's",
#  'my',
#  'multiple',
#  'detailed',
#  'Excellent.Apple',
#  'every',
#  'screen',
#  'workaround',
#  'safe.',
#  '11',
#  'OS',
#  'Lidar',
#  'wearing',
#  'Especially',
#  'Android.Just',
#  'good!!\n',
#  'market',
#  'review',
#  'clear',
#  'handle.',
#  'decent',
#  'imitations.',
#  'Android',
#  '\nExcellent',
#  'falling',
#  'tell',
#  'just',
#  'far',
#  'single',
#  'rate',
#  'fine',
#  '5',
#  'great.',
#  '16GB.\n',
#  'Amazon.\n',
#  'sensor',
#  'could',
#  'see',
#  'battery!!!.',
#  'often.',
#  'grip',
#  'complaints',
#  'product',
#  'Finish',
#  'camera',
#  'details',
#  'recommend',
#  'pro',
#  '7.4mm',
#  'major',
#  'square,',
#  'case.',
#  'view,',
#  'love',
#  'height',
#  'through',
#  'genshin',
#  'users',
#  'Oh',
#  'beated',
#  'From',
#  'mobile.The',
#  'far.',
#  'but',
#  'tele-calling,',
#  'filter',
#  '.ProsThis',
#  'tighten',
#  'network',
#  'working',
#  'explain',
#  '10',
#  '.',
#  'look.Awesome',
#  'we',
#  'ramifications.',
#  'buttery',
#  'good!',
#  'excellent',
#  'skin',
#  'stunning',
#  'other',
#  'pro.',
#  'had',
#  'stylish.The',
#  'after',
#  'sure',
#  'charm',
#  'smaller',
#  'safely',
#  '12pro',
#  'handle,',
#  '6GB',
#  'iphone12pro',
#  'new',
#  'hand-handling',
#  'user',
#  'it!!So',
#  'cams.Instead',
#  'camera.',
#  'For',
#  '1',
#  'impact',
#  'world',
#  'many',
#  'problem.',
#  'this',
#  'three',
#  'which',
#  'me',
#  'things',
#  'Amazon.Super',
#  'However,',
#  'go',
#  'was',
#  'so',
#  'glossy',
#  'environment',
#  'life',
#  'i7',
#  'may',
#  'in',
#  'slow.',
#  'wear',
#  'sleek',
#  'never',
#  'bit!!',
#  'note',
#  'though',
#  'along',
#  'invest',
#  'about',
#  'smartphone',
#  'Awesome.',
#  'feels',
#  'issues.I',
#  'you',
#  'sub-consciously',
#  'Sensor',
#  'unlock',
#  'lens',
#  'Mode.',
#  'good',
#  'X,',
#  'Make',
#  'the',
#  'design',
#  'buying',
#  'become',
#  'little',
#  'and',
#  'trying',
#  'anything.',
#  'clicking',
#  'out',
#  "isn't",
#  'worth',
#  'equally',
#  'shown',
#  'battery,',
#  'performance',
#  'imaging',
#  'fanboy',
#  '\nBeen',
#  'longer',
#  'spending',
#  'proud',
#  'its',
#  'cons',
#  '21st',
#  'surfing,',
#  'balance',
#  'eco-system',
#  'quite',
#  'very',
#  'expected',
#  '12',
#  'high',
#  'battery!!!,',
#  'fingerprint',
#  'amount',
#  'to',
#  'Symbian',
#  'cell\n',
#  'would',
#  '(11:50)',
#  'are',
#  'pic.This',
#  'hand.',
#  'jump',
#  'point',
#  'laughable.\n',
#  'Sync',
#  'bad',
#  'tones.Image',
#  'big',
#  'comfortable',
#  '5,',
#  'We',
#  '\nAs',
#  'smartphone,as',
#  'well',
#  'still',
#  '.Since',
#  'Video',
#  'gives',
#  'has',
#  'technology',
#  'maintenance',
#  'smooth',
#  'wide',
#  'Mode',
#  'drop',
#  'tones',
#  'miss',
#  'matters.The',
#  'update)I',
#  '2',
#  'sides.',
#  'shifted',
#  'highly',
#  'enough',
#  'etc.This',
#  'can',
#  'pic',
#  'ground,',
#  'correct',
#  'hanging.The',
#  'no',
#  'Many',
#  'as',
#  'then',
#  'received',
#  'means',
#  'data/chat',
#  'at',
#  '.Only',
#  'mine,',
#  'refresh',
#  'thick',
#  'It',
#  'modern',
#  'due',
#  'covid',
#  'get',
#  'light',
#  'hands',
#  'lovely',
#  'page',
#  'Amazon.',
#  'good.',
#  'dark',
#  'telephoto',
#  'palm.',
#  'awesome!',
#  'pass',
#  'RAM',
#  'issues',
#  'possible',
#  'battery.',
#  'hand',
#  'past',
#  'splendid,',
#  'without']

# %%
#Sentiment analysis
import pandas as pd
afinn = pd.read_csv('Afinn.csv', sep=',', encoding='latin-1')
afinn.shape
# Out:
# (2477, 2)

# %%
afinn.head(20)
# Out:
#           word  value
# 0      abandon     -2
# 1    abandoned     -2
# 2     abandons     -2
# 3     abducted     -2
# 4    abduction     -2
# 5   abductions     -2
# 6        abhor     -3
# 7     abhorred     -3
# 8    abhorrent     -3
# 9       abhors     -3
# 10   abilities      2
# 11     ability      2
# 12      aboard      1
# 13    absentee     -1
# 14   absentees     -1
# 15     absolve      2
# 16    absolved      2
# 17    absolves      2
# 18   absolving      2
# 19    absorbed      1

# %%
import nltk
nltk.download('punkt')
from nltk import tokenize
red_unique = tokenize.sent_tokenize(" ".join(iphone_reviews))
red_unique[5:15]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['!The filter mode is quite good.',
#  'Many Android phones are still many miles away from these tones even though there are good imitations.',
#  'Apple was able to improve its tones.Image quality is perfect and there is little or no noise even in a low-light environment .',
#  '** Signal, nothing to say!',
#  'It is much better in iPhone 12 Pro & Wifi also .ConsThere is a problem with the hand-handling of this phone.',
#  'Oh yes, the iPhone 12 is light to handle, however, it is not easy to handle.',
#  'The iPhone 12 comes with metal edges and there have been multiple complaints with respect to these edges.',
#  'If you handle this phone for a long time, as your hand becomes a bit moist, the metal becomes slippery.',
#  'To prevent your phone from falling to the ground, you will sub-consciously tighten your grip on the phone.',
#  'Several reports have shown that tightening your grip on the iPhone 12 leaves you with a scar on your palm.']

# %%
sent_df = pd.DataFrame(red_unique, columns=['word'])
sent_df
# Out:
#                                                   word
# 0    \nAs usual great & premium phone of 2020 .Pros...
# 1    It feels better than the sleek bezel of the iP...
# 2    The border is particularly stylish.The camera ...
# 3    The night view mode turns on automatically, an...
# 4              Video stabilization is also good!!!!!!!
# ..                                                 ...
# 433  Especially there is no phone in market clickin...
# 434       Graphite colour is lovely with glossy sides.
# 435  Stunning look.Awesome experience using dark mo...
# 436                   makes life so easy and seamless.
# 437     highly recommend to buy iPhone through Amazon.
#
# [438 rows x 1 columns]

# %%
affinity_scores = afinn.set_index('word')['value'].to_dict()

# %%
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
nlp = spacy.load('en_core_web_sm')
sentiment_lexicon = affinity_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        word = nlp(text)
        for word in red_unique:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

# %%
nlp = spacy.load('en_core_web_sm')
sentiment_lexicon = affinity_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

# %%
calculate_sentiment(text = 'amazing')
# Out:
# 4

# %%
sent_df['sentiment_value'] = sent_df['word'].apply(calculate_sentiment)

# %%
sent_df['word_count'] = sent_df['word'].str.split().apply(len)
sent_df['word_count'].head(10)
# Out:
# 0    32
# 1    18
# 2     8
# 3    14
# 4     5
# 5     6
# 6    17
# 7    23
# 8     5
# 9    21
# Name: word_count, dtype: int64

# %%
sent_df.sort_values(by='sentiment_value').tail(10)
# Out:
#                                                   word  sentiment_value  \
# 70   Stunning look.Awesome experience using dark mo...               11
# 61   This iPhone 12pro Is the best in all the thing...               11
# 289  Stunning look.Awesome experience using dark mo...               11
# 207  This iPhone 12pro Is the best in all the thing...               11
# 404  But overall , its good phone and worth the pri...               13
# 185  But overall , its good phone and worth the pri...               13
# 39   But overall , its good phone and worth the pri...               13
# 112  But overall , its good phone and worth the pri...               13
# 258  But overall , its good phone and worth the pri...               13
# 331  But overall , its good phone and worth the pri...               13
#
#      word_count
# 70           14
# 61           41
# 289          14
# 207          41
# 404          49
# 185          49
# 39           49
# 112          49
# 258          49
# 331          49

# %%
sent_df['sentiment_value'].describe()
# Out:
# count    438.000000
# mean       2.178082
# std        2.961272
# min       -3.000000
# 25%        0.000000
# 50%        2.000000
# 75%        3.000000
# max       13.000000
# Name: sentiment_value, dtype: float64

# %%
sent_df[sent_df['sentiment_value']<=0].head()
# Out:
#                                                  word  sentiment_value  \
# 1   It feels better than the sleek bezel of the iP...                0
# 8                          ** Signal, nothing to say!                0
# 9   It is much better in iPhone 12 Pro & Wifi also...               -2
# 11  The iPhone 12 comes with metal edges and there...                0
# 12  If you handle this phone for a long time, as y...                0
#
#     word_count
# 1           18
# 8            5
# 9           21
# 11          18
# 12          20

# %%
sent_df[sent_df['sentiment_value']>=10].head()
# Out:
#                                                   word  sentiment_value  \
# 39   But overall , its good phone and worth the pri...               13
# 61   This iPhone 12pro Is the best in all the thing...               11
# 65   I ordered the phone on 20th June at night (11:...               10
# 70   Stunning look.Awesome experience using dark mo...               11
# 112  But overall , its good phone and worth the pri...               13
#
#      word_count
# 39           49
# 61           41
# 65           27
# 70           14
# 112          49

# %%
sent_df['index']=range(0,len(sent_df))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(sent_df['sentiment_value'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(y='sentiment_value',x='index',data=sent_df)

# %%
sent_df.plot.scatter(x='word_count', y='sentiment_value', figsize=(8,8), title='Sentence sentiment value to sentence word count')
